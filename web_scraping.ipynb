# %% [markdown]
# <a href="https://colab.research.google.com/github/andrearanieri98/python-projects/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Base URL per la paginazione
base_url = 'https://books.toscrape.com/catalogue/page-{}.html'

# Lista per contenere tutti i dati
all_books = []

# Scorri le 50 pagine
for page in range(1, 51):
    print(f'🔄 Estrazione da pagina {page}...')
    url = base_url.format(page)
    response = requests.get(url)

    # Se la pagina non esiste o dà errore, esci
    if response.status_code != 200:
        print(f' Pagina {page} non trovata (errore {response.status_code}). Interrotto.')
        break

    soup = BeautifulSoup(response.text, 'html.parser')
    books = soup.find_all('article', class_='product_pod')

    # Estrai dati per ogni libro
    for book in books:
        title = book.h3.a['title']
        price = book.find('p', class_='price_color').text
        availability = book.find('p', class_='instock availability').text.strip()
        all_books.append([title, price, availability])

# Salva i dati in un CSV
df = pd.DataFrame(all_books, columns=['Titolo', 'Prezzo', 'Disponibilità'])
df.to_csv('books_all.csv', index=False)

# Mostra anteprima
print(" Estrazione completata.")
df.head()
# Out:
# 🔄 Estrazione da pagina 1...
# 🔄 Estrazione da pagina 2...
# 🔄 Estrazione da pagina 3...
# 🔄 Estrazione da pagina 4...
# 🔄 Estrazione da pagina 5...
# 🔄 Estrazione da pagina 6...
# 🔄 Estrazione da pagina 7...
# 🔄 Estrazione da pagina 8...
# 🔄 Estrazione da pagina 9...
# 🔄 Estrazione da pagina 10...
# 🔄 Estrazione da pagina 11...
# 🔄 Estrazione da pagina 12...
# 🔄 Estrazione da pagina 13...
# 🔄 Estrazione da pagina 14...
# 🔄 Estrazione da pagina 15...
# 🔄 Estrazione da pagina 16...
# 🔄 Estrazione da pagina 17...
# 🔄 Estrazione da pagina 18...
# 🔄 Estrazione da pagina 19...
# 🔄 Estrazione da pagina 20...
# 🔄 Estrazione da pagina 21...
# 🔄 Estrazione da pagina 22...
# 🔄 Estrazione da pagina 23...
# 🔄 Estrazione da pagina 24...
# 🔄 Estrazione da pagina 25...
# 🔄 Estrazione da pagina 26...
# 🔄 Estrazione da pagina 27...
# 🔄 Estrazione da pagina 28...
# 🔄 Estrazione da pagina 29...
# 🔄 Estrazione da pagina 30...
# 🔄 Estrazione da pagina 31...
# 🔄 Estrazione da pagina 32...
# ...

# %%
from google.colab import files
files.download('books_all.csv')
